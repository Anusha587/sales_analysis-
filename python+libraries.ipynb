# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV
df = pd.read_csv("C:/Users/91974/Documents/sales_data.csv")
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# %% [markdown]
# # total sales records are in the dataset?

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# Preview
df.head()
# Out:
#    OrderID       Date   Product     Category  Quantity  UnitPrice Region  \
# 0     1001 2024-01-03  notebook   Stationary         3        5.5  North
# 1     1002 2024-01-05    pencil   Stationary        10        0.5  South
# 2     1003 2024-01-07      desk    furniture         1       85.5   West
# 3     1004 2024-01-09   moniter  Electronics         2      120.0   East
# 4     1005 2024-01-11    laptop  Electronics         1      659.5  North
#
#    Revenue
# 0     16.5
# 1      5.0
# 2     85.5
# 3    240.0
# 4    659.5

# %% [markdown]
# # What is the overall revenue generated?

# %%
total_revenue = df['Revenue'].sum()
print("Total Revenue: $", total_revenue)
# Out:
# Total Revenue: $ 2021.2

# %% [markdown]
# # Which product category generated the highest revenue?

# %%
category_sales = df.groupby("Category")['Revenue'].sum()
print(category_sales)
category_sales.plot(kind='bar', title="Revenue by Category")
plt.ylabel("Revenue")
plt.show()
# Out:
# Category
# Electronics    1874.5
# Stationary       44.7
# furniture       102.0
# Name: Revenue, dtype: float64

# %% [markdown]
# # Which region contributed the most to sales?

# %%
region_sales = df.groupby("Region")['Revenue'].sum()
print(region_sales)
region_sales.plot(kind='pie', autopct='%1.1f%%', title="Revenue by Region")
plt.ylabel("")
plt.show()
# Out:
# Region
# East     256.5
# North    698.0
# South     80.0
# West     986.7
# Name: Revenue, dtype: float64

# %% [markdown]
# # What are the daily sales trends over time?

# %%
df.groupby("Date")['Revenue'].sum().plot(kind='line', marker='o')
plt.title("Daily Sales Trend")
plt.ylabel("Revenue")
plt.xlabel("Date")
plt.grid(True)
plt.show()

# %% [markdown]
# # What is the summary statistics of sales?

# %%
print(df.describe())
# Out:
#           OrderID                 Date   Quantity   UnitPrice     Revenue
# count    10.00000                   10  10.000000   10.000000   10.000000
# mean   1005.50000  2024-01-12 00:00:00   3.300000  106.470000  202.120000
# min    1001.00000  2024-01-03 00:00:00   1.000000    0.500000    1.200000
# 25%    1003.25000  2024-01-07 12:00:00   1.000000    5.500000   16.500000
# 50%    1005.50000  2024-01-12 00:00:00   2.500000   18.500000   48.500000
# 75%    1007.75000  2024-01-16 12:00:00   4.500000  111.375000  201.375000
# max    1010.00000  2024-01-21 00:00:00  10.000000  659.500000  900.000000
# std       3.02765                  NaN   2.945807  201.814844  317.631075
